# %%
#Properties of Tuple

tupleOne=("user1","user2","user3")  #ordered
print(tupleOne)
# tuple.append("user4")    #immutable can't change after creation
# print(tupleOne)
# print(tupleOne[1])    #indexed 

# print(tupleOne[0:2]) #slicing
# print(tupleOne[0:])
# print(tupleOne[:3])
# print(tupleOne[:])
# print(tupleOne[: : 1])  #print as it is 
# print(tupleOne[: : 2])  #print after taking one gap
# print(tupleOne[: : -1]) #  print reverse using -ve index
# print(tupleOne[: : -2])
# print(tupleOne[: :-3])
# print(tupleOne[-1])
# for i in tupleOne:  #iterable
#     print(i)   #print each in next line
    # print(i, end=" ")  # print in one line

for i , j in enumerate(tupleOne):
    if i == 1:
        continue
    print(i,j)
# Out:
# ('user1', 'user2', 'user3')
# 1 user2
# 2 user3

# %%
tupleOne=("user1","user2","user3",10,20,True)   #homo
tupleOne=("user1","user2","user3","user4")       #hetro
print(tupleOne)
# Out:
# ('user1', 'user2', 'user3', 'user4')

# %%
tupleOne=("user1","user2","user3","user4","user2","user3")
#           0       1       2       3       4       5   +ve
#          -6       -5     -4     -3        -2     -1   -ve
print(tupleOne[2])
print(tupleOne[-2])
# Out:
# user3
# user2

# %%
tupleOne=("user1","user2","user3") 
tupleTwo=("user4","user5")
res=tupleOne+tupleTwo                   #concatenation
print(res)
# Out:
# ('user1', 'user2', 'user3', 'user4', 'user5')

# %% [markdown]
# Methods of Tuple
# count()
# index()

# %%
tupleOne=("user1","user2","user3","user4")
print(tupleOne.count("user1"))    #count

print(tupleOne.index("user1"))     #index
# Out:
# 1
# 0

# %%
# tupleOne=("user1","user2","user3","user4")
# print(len(tupleOne))
# print(min(tupleOne))
# print(max(tupleOne))

tupleOne=("demo","user",1,2)
print(ord("d"),ord("u"))
print(chr(1),chr(2))
# Out:
# 100 117

# %%
tupleOne = [10, 20, 30, 40, 50]

newtuple = []

for i in tupleOne:
    newtuple = [i] + newtuple

print(newtuple)
# Out:
# [50, 40, 30, 20, 10]
