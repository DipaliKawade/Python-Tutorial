# %%
##Properties

str1= "demoUser"
for i in str1:
    if i=="u":
        continue
    print(i, end="")
# Out:
# demoUser

# %%
students=["dipali","divya","shubh"]     #odered..element  follow fixed order
#           0   ,      1    ,   2
print(students)
print(id(students))
students.append("shwetali")  #can change after Creation i.e mutable
print(students)
print(id(students))
print(students[2])      #indexed   access index using elements
# Out:
# ['dipali', 'divya', 'shubh']
# 3208645910400
# ['dipali', 'divya', 'shubh', 'shwetali']
# 3208645910400
# shubh

# %%
students=["dipali","divya","shubh","Swati"]     
#           0   ,      1    ,   2 ,     3
# [start: end : steps]  slicing
print(students[0:3])
print(students[:3])
print(students[0:])
print(students[:])
print(students[::2])
print(students[::3])
# Out:
# ['dipali', 'divya', 'shubh']
# ['dipali', 'divya', 'shubh']
# ['dipali', 'divya', 'shubh', 'Swati']
# ['dipali', 'divya', 'shubh', 'Swati']
# ['dipali', 'shubh']
# ['dipali', 'Swati']

# %%
students=["dipali","divya","shubh","Swati"]     
#           0   ,      1    ,   2 ,     3
for i in students:
    print(i,end=" ")  #iterable
# Out:
# dipali divya shubh Swati

# %%
students=["dipali","divya","shubh","Swati","dipali","divya"]     
#           0   ,      1    ,   2 ,     3
print(students)
set1=set(students)   #allowed duplicates
# Out:
# ['dipali', 'divya', 'shubh', 'Swati', 'dipali', 'divya']

# %%
listone=["user1",55,True]
print(listone)      #homogenious
# Out:
# ['user1', 55, True]

# %%
listone=["user1",55,[4,5,6,[6,7,8]],True]
print(listone)
print(listone[3])
print(listone[2])
print(listone[2][1])
print(listone[2][3])
# Out:
# ['user1', 55, [4, 5, 6, [6, 7, 8]], True]
# True
# [4, 5, 6, [6, 7, 8]]
# 5
# [6, 7, 8]

# %%
students=["dipali","divya","shubh","Swati","dipali","divya"]   
# +ve       0   ,   1   ,   2   ,   3,      ,   4,      5
#-ve      -6        -5        -4      -3      -2      -1
print(students[-3])
print(students[3])
# Out:
# Swati
# Swati

# %%
listone=["user1"]
listtwo=["user2"]
res=listtwo+listone
print(res)
# Out:
# ['user2', 'user1']

# %% [markdown]
# Methods of Lists

# %%
#to add

listone=["user1","user2","user3"]
print(listone)

listone.append("dipali")
print(listone)

temp=["user4","user5"]
listone.extend(temp)
print(listone)

listone.insert(2,"user6")
print(listone)

# to remove

# listone.remove("user3")
# print(listone)

# listone.pop(0)
# print(listone)

# listone.clear()
# print(listone)

print(listone.index("user3"))

print(listone.count("user3"))
# Out:
# ['user1', 'user2', 'user3']
# ['user1', 'user2', 'user3', 'dipali']
# ['user1', 'user2', 'user3', 'dipali', 'user4', 'user5']
# ['user1', 'user2', 'user6', 'user3', 'dipali', 'user4', 'user5']
# 3
# 1

# %%
nums=[4,5,3,7,2,9,1,10,15,13]
print(nums)

nums.sort
#print(sorted(nums))
print(nums)

nums.reverse()
print(nums)
# Out:
# [4, 5, 3, 7, 2, 9, 1, 10, 15, 13]
# [4, 5, 3, 7, 2, 9, 1, 10, 15, 13]
# [13, 15, 10, 1, 9, 2, 7, 3, 5, 4]

# %%
listone=["user1","user2"]
print("original :",listone)
print(id(listone))

copyone=listone.copy()
print("copy1:  ",copyone)
print(id(copyone))

copytwo=listone.copy()
print("copy2:  ",copytwo)
print(id(copytwo))
# Out:
# original : ['user1', 'user2']
# 1300297194432
# copy1:   ['user1', 'user2']
# 1300297195136
# copy2:   ['user1', 'user2']
# 1300297141248

# %%
listone=["user1","User2"]

nums=[1,2,3,4,5]

print(len(listone))

print(max(nums))
print(ord("u"),ord("U"))
print(max(listone))

print(min(nums))
print(min(listone))

print(sum(nums))
# print(sum(listone))
print(sorted(nums))
print(type(nums))
# Out:
# 2
# 5
# 117 85
# user1
# 1
# User2
# 15
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
nums=[8,2,3,1,5]
print(nums)

tuple1=tuple(nums)
print(tuple1)

set1=set(nums)
print(set1)

str1=str(nums)
print(str1)     #[8, 2, 3, 1, 5]
# Out:
# [8, 2, 3, 1, 5]
# (8, 2, 3, 1, 5)
# {1, 2, 3, 5, 8}
# [8, 2, 3, 1, 5]

# %%
students=["user1","user2","user3"]
for i,j in enumerate(students):
    print(i,j)

print(" ".join(reversed(students)))
# Out:
# 0 user1
# 1 user2
# 2 user3
# user3 user2 user1

# %%
students=["False","False",0]
print(any(students))
print(all(students))

student=["False","False",0,0]
print(any(student))
print(all(student))
# Out:
# True
# False
# True
# False
