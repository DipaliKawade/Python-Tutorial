# %%
#Properties

setOne={"one","two","three","four","one"}
print(setOne)                      #unorderd

setOne.add("five")          #mutable
print(setOne)               #not allowed duplication

# print(setOne[1])            #not allow indexed it is unindexed


# print(setOne)
# Out:
# {'four', 'two', 'three', 'one'}
# {'four', 'five', 'one', 'three', 'two'}
