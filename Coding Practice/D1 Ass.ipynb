# %%
# Personal Profile Program

name = "Dipali Kawade"
age = 21
college_name = "PES Modern College of Engineering Pune"
city = "Pune"
course_name = "Electronics and Telecommunication Engineering (ENTC)"

print("========== PERSONAL PROFILE ==========")
print("Name         :", name)
print("Age          :", age)
print("College Name :", college_name)
print("City         :", city)
print("Course Name  :", course_name)
print("======================================")
# Out:
# ========== PERSONAL PROFILE ==========
# Name         : Dipali Kawade
# Age          : 21
# College Name : PES Modern College of Engineering Pune
# City         : Pune
# Course Name  : Electronics and Telecommunication Engineering (ENTC)
# ...

# %%
# Student Report Program

student_name = "Dipali Kawade"
roll_number = 101
branch = "Electronics and Telecommunication Engineering (ENTC)"
percentage = 85.6
passed = True

print("========== STUDENT REPORT ==========")
print("Student Name :", student_name)
print("Roll Number  :", roll_number)
print("Branch       :", branch)
print("Percentage   :", percentage, "%")
print("Passed       :", passed)
print("====================================")
# Out:
# ========== STUDENT REPORT ==========
# Student Name : Dipali Kawade
# Roll Number  : 101
# Branch       : Electronics and Telecommunication Engineering (ENTC)
# Percentage   : 85.6 %
# Passed       : True
# ...

# %%
# Identifier Practice

student_name = "Dipali Kawade"
roll_no = 101
college_name = "PES Modern College of Engineering"
branch = "ENTC"
semester = 7
section = "A"
attendance_percentage = 92.5
cgpa = 8.75
course_name = "Python Programming"
is_hosteller = False

print("========== COLLEGE MANAGEMENT SYSTEM ==========")
print("Student Name          :", student_name)
print("Roll Number           :", roll_no)
print("College Name          :", college_name)
print("Branch                :", branch)
print("Semester              :", semester)
print("Section               :", section)
print("Attendance Percentage :", attendance_percentage, "%")
print("CGPA                  :", cgpa)
print("Course Name           :", course_name)
print("Hosteller             :", is_hosteller)
print("===============================================")
# Out:
# ========== COLLEGE MANAGEMENT SYSTEM ==========
# Student Name          : Dipali Kawade
# Roll Number           : 101
# College Name          : PES Modern College of Engineering
# Branch                : ENTC
# Semester              : 7
# Section               : A
# Attendance Percentage : 92.5 %
# CGPA                  : 8.75
# Course Name           : Python Programming
# Hosteller             : False
# ...

# %%
# This program prints my introduction.
# It demonstrates the use of comments in Python.
# Author: Dipali Kawade

"""
This is a multi-line comment.
It explains that the program displays
basic information about the student.
"""

print("Hello Everyone!")
print("My name is Dipali Kawade.")
print("I am pursuing Electronics and Telecommunication Engineering (ENTC).")
print("I study at PES Modern College of Engineering, Pune.")
print("I am learning Python programming and interested in AI and software development.")
print("Thank you!")
# Out:
# Hello Everyone!
# My name is Dipali Kawade.
# I am pursuing Electronics and Telecommunication Engineering (ENTC).
# I study at PES Modern College of Engineering, Pune.
# I am learning Python programming and interested in AI and software development.
# Thank you!

# %%
# Corrected variable names

student2 = "Dipali Kawade"      # Corrected from 2student
student_name = "Dipali"         # Corrected from student-name
student_name_full = "Dipali Kawade"  # Corrected from student name
class_name = "ENTC"             # Corrected from class
for_loop = 10                   # Corrected from for
employee_id = "EMP101"          # Corrected from employee@id

# Print all variables
print("Student 2        :", student2)
print("Student Name     :", student_name)
print("Full Name        :", student_name_full)
print("Class Name       :", class_name)
print("For Loop Value   :", for_loop)
print("Employee ID      :", employee_id)
# Out:
# Student 2        : Dipali Kawade
# Student Name     : Dipali
# Full Name        : Dipali Kawade
# Class Name       : ENTC
# For Loop Value   : 10
# Employee ID      : EMP101
