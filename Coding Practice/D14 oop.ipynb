# %% [markdown]
# 12 august 2026

# %%
""" 1. Student Information System
Create a Student class with:
• name
• roll_no
• branch
• marks
Create 3 student objects and create a method display() to print their details."""

class Student:
    def __init__(self, name, roll_no, branch, marks):
        self.name = name
        self.roll_no = roll_no
        self.branch = branch
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Branch:", self.branch)
        print("Marks:", self.marks)
        print()


# Creating 3 student objects
s1 = Student("Dipali", 101, "Computer", 87)
s2 = Student("Shubhangi", 102, "IT", 91)
s3 = Student("Divya", 103, "ENTC", 85)

s1.display()        #isplay details
s2.display()
s3.display()
# Out:
# Name: Dipali
# Roll No: 101
# Branch: Computer
# Marks: 87
#
# Name: Shubhangi
# Roll No: 102
# Branch: IT
# Marks: 91
#
# Name: Divya
# Roll No: 103
# Branch: ENTC
# Marks: 85

# %%
"""2. Employee Salary
Create an Employee class with:
• name
• employee_id
• salary
Create a method display_salary() that displays the employee's salary.
Create 3 employee objects.
: Don't assign the values directly inside the class. Pass them while creating objects."""

class Employee:
    def __init__(self, name, employee_id, salary):
        self.name = name
        self.employee_id = employee_id
        self.salary = salary

    def display_salary(self):
        print("Name:", self.name)
        print("Employee ID:", self.employee_id)
        print("Salary:", self.salary)
        print()


# Creating 3 employee objects
e1 = Employee("Rahul", 101, 35000)
e2 = Employee("Priya", 102, 42000)
e3 = Employee("Amit", 103, 50000)

e1.display_salary()     # Display salary
e2.display_salary()
e3.display_salary()
# Out:
# Name: Rahul
# Employee ID: 101
# Salary: 35000
#
# Name: Priya
# Employee ID: 102
# Salary: 42000
#
# Name: Amit
# Employee ID: 103
# Salary: 50000

# %%
""" 3. Mobile Phone
Create a Mobile class with:
• brand
• model
• price
Create a method:
display_details()
Create 3 mobile objects with different information.
Expected concept: Constructor + objects """

class Mobile:
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price

    def display_details(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Price:", self.price)
        print("--------------------")


# Creating 3 Mobile objects
m1 = Mobile("Samsung", "Galaxy S24", 75000)
m2 = Mobile("Apple", "iPhone 15", 70000)
m3 = Mobile("OnePlus", "OnePlus 12", 60000)

m1.display_details()        # Display salary
m2.display_details()
m3.display_details()
# Out:
# Brand: Samsung
# Model: Galaxy S24
# Price: 75000
# --------------------
# Brand: Apple
# Model: iPhone 15
# Price: 70000
# --------------------
# Brand: OnePlus
# Model: OnePlus 12
# Price: 60000
# --------------------
